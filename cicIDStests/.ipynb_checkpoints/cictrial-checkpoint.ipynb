# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("income.csv")
df
# Out:
#       Name  Destination Prt  Noth thing   Total Fwd Packets  \
# 0      Rob            54865           3                   2
# 1  Michael            55054         109                   1
# 2    Mohan            55055          52                   1
# 3   Ismail            46236          34                   1
# 4     Kory            54863           3                   2
# 5   Gautam            54871        1022                   2
# 6    David            54925           4                   2
# 7   Andrea            54925          42                   1
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
# 5                        0                           12
# ...

# %%
plt.scatter(df['Noth thing'],df['Total Length of Fwd Packets'])
